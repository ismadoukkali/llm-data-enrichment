# %% [markdown]
# ### industryGPT - Client Foils
#
# This is a python notebook to illustrate the system used for client Foils to classify potential prospect companies. The way to do this is by enriching the basic set of useful data points to filter potential target accounts.
#
# Here is the data points enriched in this specific demo:
# - **Industry**: Industry in which the company operates.
# - **Business Model**: Business Model in which the company operates.
# - **Client Focus**: Subset of customer business models does the company target.
# - **End Buyer**: Subset of departments the company targets.
# - **Innovation Challenges**: Potential data points the company would be interested in enriching.

# %%
from openai import OpenAI
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import time
import os
from googlesearch import search
from dotenv import load_dotenv
from datetime import datetime
import json
import pandas as pd

# %% [markdown]
# ##### OpenAI functions

# %%
load_dotenv()
client = OpenAI()

def generate_response(prompt):
    response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_gpt3(prompt):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    max_tokens=300,
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

# %% [markdown]
# #### Scrapping function

# %%
def retrieve_html(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    req = Request(url, headers=headers)
    html = urlopen(req).read()
    soup = BeautifulSoup(html, features="html.parser")

    for script in soup(["script", "style"]):
        script.extract() 

    text = soup.get_text()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

# %%
def selenium_search(query):
    for url in search(query + ' website', lang = 'en'):
        return url

# %% [markdown]
# #### Client Focus Prompt

# %%
client_focus = ["B2C", "B2B", "B2B/B2C"]
prompt_client_focus = """

You are given the description of a company retrieved from a company's website.

You will need to categorize the company within a Client Focus according to the taxonomy below.

There can only be ONE client focus. The answer needs to be concise and only can follow the taxonomy.

DO NOT come up with any taxonomy. STICK to the taxonomy below. 

Give your results in the format JSON  - 

'client_focus': [client focus] 


Here the taxonomy for the client focus:
B2C
B2B
B2B/B2C
"""

# %% [markdown]
# #### Industry Prompt

# %%
startup_industries = ["Building Materials", "Business Intelligence", "Cannabis", "Civil Engineering Construction", "Cloud Infrastructure", "Collaboration", "Commercial Recycling & Waste Management", "Contract Management", "Corporate Social Responsibility (CSR) Solutions", "Customer Relationship Management (CRM)", "Database & File Management", "Digital Transformation Consulting", "E-Commerce", "Electronics", "Emergency & Law Enforcement", "Employee Compensation", "Energy, Utilities & Waste", "Engineering Software", "Enterprise Resource Planning (ERP)", "Event Management", "Events Services", "Facilities Management & Commercial Cleaning", "Financial Services", "Food & Beverage", "Freight & Logistics", "Gaming", "Health, Beauty & Fitness", "Healthcare", "Hospitaltiy Management Systems", "Human Resources (HR)", "Human Resources Consulting", "Innovation Management Consulting", "Internet Publishing & Classifieds", "IT & Infrastructure", "Leasing Non-Residential Real Estate", "Legal", "Managed It Services", "Management Consulting", "Market Intelligence Platform", "Market Research", "Marketing & Advertising", "Media & Entertainment", "Medical Devices & Equipment", "Miscellaneous Manufacturing", "Multimedia & Graphic Design", "Oil & Gas Exploration", "On Demand Delivery", "On Demand Services", "On Demand Transportation", "Payments Infrastructure & Solutions Provider", "Payroll & Benefits", "Procurement Solutions", "Productivity & Automation", "Real Estate", "Research & Development", "Robotics", "Sales & Lead Generation", "Security & Compliance", "Security Products & Services", "Staffing & Recruiting", "Storage Solutions Provider", "Supply Chain Management (SCM)", "Telephony & Wireless", "Textiles & Apparel", "Training & Education", "Translation & Linguistic Services", "Travel & Expense Management", "Video Games Distribution", "Video Games Production"]

prompt_industry_business =  f"""

You are given the description of a company retrieved from a company's website.

You will need to categorize the company within their Industry and Business Model Category according to the taxonomy below.

There can only be ONE industry and ONE business model. The answer needs to be concise and only can follow the taxonomy.

DO NOT come up with any taxonomy. STICK to the taxonomy below. 

Give your results in the format format JSON - 

'industry': [industry] 
'business_model': [business model]

Here the taxonomy for each of the Industries and Business Models - 

Business Models:
SaaS
Marketplace
Ecommerce
Service
Manufacturing 

Industries:

"""

# %% [markdown]
# #### End Buyer Prompt

# %%
end_buyer = ["Sales", "Marketing", "HR", "Finance", "Tech & Data", "Legal", "Procurement", "Client support", "CSE", "ESG", "Communication", "Consumer"]
prompt_end_buyer =  f"""

You are given the description of a company retrieved from a company's website.

You will need to categorize the company within an End Buyer category according to the taxonomy below.

There can only be ONE end buyer The answer needs to be concise and only can follow the taxonomy.

DO NOT come up with any taxonomy. STICK to the taxonomy below. 

Give your results in the format format JSON - 

'end_buyer': [end buyer] 

Here the taxonomy for each of the Industries and Business Models - 

End Buyer:
Sales
Marketing
HR
Finance
Tech & Data
Legal
Procurement
Client support
CSE
ESG
Communication
Consumer
"""

# %% [markdown]
# #### Sector and Innovation challenges prompt

# %%
challenges_prompt = ''' 

You are given the description of a company retrieved from a company's website.

You will need to explain in very short words the sector & innovation challenges that they might be facing.

Give your results in the format format JSON - 

'sector_challenge': [challenges of the sector] 
'innovation_challenge': [challenges of innovation]
'''

# %%
header_url= "Here their description deducted from their website: "
organize_prompt = 'Rewrite the following scrapped text from a company main website. Explain what the business does. The text will be poorly written, take that in mind. Make the description short and concise. Here the scrapped text: '

# %%
def truncate_string(input_string):
    if len(input_string) <= 3000:
        return input_string
    else:
        return input_string[:3000]

def format_url(url):
    if url.startswith("http://www."):
        url = url.replace("http://www.", "https://www.")
    elif url.startswith("http://"):
        url = url.replace("http://", "https://www.")
    elif url.startswith("www."):
        url = "https://" + url
    elif not url.startswith("https://"):
        url = "https://www." + url
    return url

# %%
def parse_response(input_string):
    lines = input_string.split('\n')
    pairs = [line.split(':') for line in lines]
    pairs = [[key.strip(), value.strip()] for key, value in pairs]
    data = dict(pairs)
    industry = data.get('Industry')
    business_model = data.get('Business Model')

    return industry, business_model

# %%
def business_status(company_employees, company_founded_date):
    company_age = 2024 - company_founded_date

    if company_employees < 200 and company_age <= 5 or company_employees < 200:
        return 'Startup'
    elif (201 <= company_employees <= 1000 and 3 <= company_age < 15) or 501 <= company_employees <= 1000:
        return 'MidMarket'
    elif (company_employees >= 1001 or company_age >= 15) or company_employees >= 1001:
        return 'Corporate'
    else:
        return 'Uncategorized'

# %%
def industryGPT(name, url):
    print('Enriching: ', name)
    print('With URL: ', url)

    full_response = {
            "metadata": {
                "timestamp": str(datetime.now()),
                "source": "industryGPT"
            },
            "company_profile": {
                "website": None,
                "business_status": None,
                "industry": None,
                "business_model": None,
                "end_buyer": None,
                "client_focus": None,
                "description": None,
                "sector_challenge": None,
                "innovation_challenge": None
            }

        }
    
    # Categorise industry & business model
    url_text = retrieve_html(format_url(url))
    print('\n-> Retrieved text from website...')
    
    if len(url_text) > 100:
        print('-> Crafting company description...')
        description_openai = generate_response_gpt3(organize_prompt + truncate_string(url_text))
        print('\nDescription of the company: ', description_openai)

    else:
        print('Scrapped website has less than 100 characters...')
        print('Trying to search on google a new page...')
        new_url = selenium_search(format_url(url))
        url_text = retrieve_html(new_url)
        description_openai = generate_response_gpt3(organize_prompt + truncate_string(url_text))
        print('\nDescription of the company: ', description_openai)

    # Save description
    full_response["company_profile"]["description"] = description_openai

    industry_categories = startup_industries
    selected_industries = ', '.join(industry_categories)

    # Categorise industry & business Model
    response_industry = generate_response(prompt_industry_business +
                                selected_industries +
                                header_url +
                                description_openai)
    
    response_dict_industry = json.loads(response_industry)
    full_response["company_profile"]["industry"] = response_dict_industry["industry"]
    full_response["company_profile"]["business_model"] = response_dict_industry["business_model"]

    # Categorise client focus
    response_clientfocus = generate_response(prompt_client_focus +
                                header_url +
                                description_openai)
    
    response_dict_clientfocus = json.loads(response_clientfocus)
    full_response["company_profile"]["client_focus"] = response_dict_clientfocus["client_focus"]

    # Categorise end buyer
    response_endbuyer = generate_response(prompt_end_buyer +
                                header_url +
                                description_openai)
    
    response_dict_endbuyer = json.loads(response_endbuyer)
    full_response["company_profile"]["end_buyer"] = response_dict_endbuyer["end_buyer"]

    # Categorise challenges of the sector and of innovation
    response_challenges = generate_response(challenges_prompt +
                                header_url +
                                description_openai)
    
    response_dict_challenges = json.loads(response_challenges)
    full_response["company_profile"]["sector_challenge"] = response_dict_challenges["sector_challenge"]
    full_response["company_profile"]["innovation_challenge"] = response_dict_challenges["innovation_challenge"]
    

    full_response_json = json.dumps(full_response)

    json_string_pretty = json.dumps(full_response, indent=2)
    print('')
    print(json_string_pretty)

    return full_response_json

# %% [markdown]
# #### Demo for Foils

# %%
# Inputting 'Name', 'Website', 'Company_ID', 'Employee Count', 'Founded Date'

industryGPT('Adopt​ Parfums', 'https://www.aluminiumdunkerque.fr/')
# Out:
# Enriching:  Adopt​ Parfums
# With URL:  https://www.aluminiumdunkerque.fr/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Aluminium Dunkerque is a company that specializes in the fabrication of aluminum plates and rolling ingots. They are committed to accelerating the decarbonization of their aluminum production. The company is involved in various projects, including the construction of an eighth furnace dedicated to recycling and the conversion of electrolysis tanks for low-energy consumption. They also prioritize safety, environmental sustainability, and community engagement.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:56:34.200447",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Miscellaneous Manufacturing",
#     "business_model": "Manufacturing",
#     "end_buyer": "Procurement",
#     "client_focus": "B2B",
#     "description": "Aluminium Dunkerque is a company that specializes in the fabrication of aluminum plates and rolling ingots. They are committed to accelerating the decarbonization of their aluminum production. The company is involved in various projects, including the construction of an eighth furnace dedicated to recycling and the conversion of electrolysis tanks for low-energy consumption. They also prioritize safety, environmental sustainability, and community engagement.",
#     "sector_challenge": [
#       "High energy consumption and costs",
#       "Greenhouse gas emissions and carbon footprint",
#       "Competition from low-cost producers",
#       "Fluctuating raw material prices",
#       "Meeting strict environmental regulations",
#       "Supply chain sustainability and transparency",
#       "Adapting to changing market demands for aluminum products"
#     ],
#     "innovation_challenge": [
#       "Developing and implementing low-energy electrolysis technology",
#       "Creating more efficient recycling processes",
#       "Reducing overall production costs while maintaining quality",
#       "Innovating to achieve carbon-neutral or carbon-negative processes",
#       "Ensuring the safety and well-being of workers during technological upgrades",
#       "Engaging with the community and stakeholders during the transition to greener practices",
#       "Balancing short-term financial objectives with long-term sustainability investments"
#     ]
#   }
# }
# '{"metadata": {"timestamp": "2023-12-05 15:56:34.200447", "source": "industryGPT"}, "company_profile": {"website": null, "business_status": null, "industry": "Miscellaneous Manufacturing", "business_model": "Manufacturing", "end_buyer": "Procurement", "client_focus": "B2B", "description": "Aluminium Dunkerque is a company that specializes in the fabrication of aluminum plates and rolling ingots. They are committed to accelerating the decarbonization of their aluminum production. The company is involved in various projects, including the construction of an eighth furnace dedicated to recycling and the conversion of electrolysis tanks for low-energy consumption. They also prioritize safety, environmental sustainability, and community engagement.", "sector_challenge": ["High energy consumption and costs", "Greenhouse gas emissions and carbon footprint", "Competition from low-cost producers", "Fluctuating raw material prices", "Meeting strict environmental regulations", "Supply chain sustainability and transparency", "Adapting to changing market demands for aluminum products"], "innovation_challenge": ["Developing and implementing low-energy electrolysis technology", "Creating more efficient recycling processes", "Reducing overall production costs while maintaining quality", "Innovating to achieve carbon-neutral or carbon-negative processes", "Ensuring the safety and well-being of workers during technological upgrades", "Engaging with the community and stakeholders during the transition to greener practices", "Balancing short-term financial objectives with long-term sustainability investments"]}}'

# %% [markdown]
# Enriching with .csv from test

# %%
account = pd.read_csv('/Users/ismadoukkali/Desktop/industryGPT/industryGPT/foils/Feuille enrichissement.csv')
account
# Out:
#                                 Entreprise  \
# 0                                      JJA
# 1                      Laboratoires Vivacy
# 2                           Legrand France
# 3                                    Lucca
# 4                 Maison Francis Kurkdjian
# 5                        Mathematic Studio
# 6                                    McPhy
# 7                                   Imerys
# 8                                 MONTEIRO
# 9                                  NovAliX
# 10                                Phosphea
# 11                                 Pigment
# 12                      POTEZ AERONAUTIQUE
# 13                  PÂTISSERIES GOURMANDES
# 14                                     RCM
# 15                                   Roxel
# 16                      Saint Algue France
# 17                    SERB Pharmaceuticals
# 18                            SES-imagotag
# 19  SOSUCAM (Société Sucrière du Cameroun)
# 20                  TCL Electronics Europe
# 21                   Telemecanique Sensors
# 22                               Trace One
# 23                               UUDS AERO
# 24                                  Verkor
# 25                          123 Pare-brise
# 26          ACC - Automotive Cells Company
# 27                                     ACH
# 28                          Adopt​ Parfums
# 29                     Aluminium Dunkerque
# 30              Ampere Software Technology
# 31                              Aroma-Zone
# 32                   Biscuit International
# 33                                  Eramet
# 34                                     TSE
# 35            Cegelec CEM (VINCI Energies)
# 36                                 Clayens
# 37                                     CTI
# 38                            Cuisine Plus
# 39                                 Cyclife
# 40                                  Deepki
# 41                                 Electra
# 42                                 Emotors
# 43                              EPC Groupe
# 44                          FAREVA AMBOISE
# 45                           FLYING WHALES
# 46                                 GILBERT
# 47                           Groupe intuis
# 48                           Groupe Pilote
# 49                                     IGL
#
#                                                   URL  Enjeu d'innovation   \
# 0                              https://www.jja-sa.fr/                  NaN
# 1                              https://vivacy.com/fr/                  NaN
# 2   https://www.legrand.fr/?gad_source=1&gclid=Cjw...                  NaN
# 3                               https://www.lucca.fr/                  NaN
# 4   https://www.franciskurkdjian.com/eu-fr?gad_sou...                  NaN
# 5                              https://mathematic.tv/                  NaN
# 6                               https://mcphy.com/fr/                  NaN
# 7                           https://www.imerys.com/fr                  NaN
# 8    https://www.monteiro-fr.com/qui-sommes-nous.html                  NaN
# 9                                https://novalix.com/                  NaN
# 10                       https://www.phosphea.com/fr/                  NaN
# 11                      https://www.gopigment.com/fr/                  NaN
# 12                             https://www.potez.com/                  NaN
# 13             https://www.patisseriesgourmandes.com/                  NaN
# 14                              https://www.myrcm.eu/                  NaN
# 15                        https://www.roxelgroup.com/                  NaN
# 16                       https://www.saint-algue.com/                  NaN
# 17                                  https://serb.com/                  NaN
# 18                   https://www.ses-imagotag.com/fr/                  NaN
# 19   https://www.somdiaa.com/groupe/filiales/sosucam/                  NaN
# 20                          https://www.tcl.com/eu/en                  NaN
# 21             https://telemecaniquesensors.com/ca/fr                  NaN
# 22                       https://www.traceone.com/fr/                  NaN
# 23            https://www.aero.uuds.com/index-fr.html                  NaN
# 24                                https://verkor.com/                  NaN
# 25                       https://www.123parebrise.fr/                  NaN
# 26                       https://www.acc-emotion.com/                  NaN
# 27        https://www.ach-france.com/pages/index.php3                  NaN
# 28               https://www.adopt.com/fr/parfum.html                  NaN
# 29                 https://www.aluminiumdunkerque.fr/                  NaN
# 30                           https://www.ampere.cars/                  NaN
# 31                        https://www.aroma-zone.com/                  NaN
# 32              https://www.biscuitinternational.com/                  NaN
# 33                         https://www.eramet.com/fr/                  NaN
# 34                                https://tse.energy/                  NaN
# 35                        https://www.cegelec-cem.fr/                  NaN
# 36                           https://www.clayens.com/                  NaN
# 37                       https://www.ctindustries.fr/                  NaN
# 38                       https://www.cuisine-plus.fr/                  NaN
# 39                       https://www.cyclife-edf.com/                  NaN
# 40                         https://www.deepki.com/fr/                  NaN
# 41                     https://www.go-electra.com/fr/                  NaN
# 42                               https://emotors.com/                  NaN
# 43                        https://www.epc-groupe.com/                  NaN
# 44                          https://www.fareva.com/fr                  NaN
# 45                     https://www.flying-whales.com/                  NaN
# 46                        https://www.labogilbert.fr/                  NaN
# 47                              https://www.intuis.fr                  NaN
# 48                         https://groupe-pilote.com/                  NaN
# 49                             https://igl-group.com/                  NaN
#
#     Enjeux du secteur
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN

# %%
df = account
df['Industry'] = None
df['Business Model'] = None
df['End Buyer'] = None
df['Client Focus'] = None
df['Innovation Challenges'] = None
df['Sector Challenges'] = None

df = pd.read_csv('/Users/ismadoukkali/Desktop/industryGPT/industryGPT/foils/enriched_foils_1.csv')

for index, row in df.iterrows():
    if index >= 40:
        name = row['Entreprise']
        website = row ['URL']
        results = industryGPT(name, website)
        response_json = json.loads(results)
        df.at[index, 'Industry'] = response_json["company_profile"]["industry"]
        df.at[index, 'Business Model'] = response_json["company_profile"]["business_model"]
        df.at[index, 'End Buyer'] = response_json["company_profile"]["end_buyer"]
        df.at[index, 'Client Focus'] = response_json["company_profile"]["client_focus"]
        df.at[index, 'Innovation Challenges'] = response_json["company_profile"]["innovation_challenge"]
        df.at[index, 'Sector Challenges'] = response_json["company_profile"]["sector_challenge"]
        df.to_csv('enriched_foils_2.csv', index=False)
# Out:
# Enriching:  Deepki
# With URL:  https://www.deepki.com/fr/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Deepki is a global leader in ESG (Environmental, Social, and Governance) solutions for the real estate industry. We help maximize the value of your real estate portfolio by guiding you through the transition to a more sustainable and environmentally friendly approach. With our comprehensive solutions, we monitor millions of square meters across multiple countries, detecting and achieving significant CO₂ emission savings. Our mission is to preserve the planet by making real estate more virtuous. Join our community of environmentally conscious real estate professionals and let us help you make a positive impact. Contact us for more information.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:47:49.292072",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Real Estate",
#     "business_model": "SaaS",
#     "end_buyer": "ESG",
#     "client_focus": "B2B",
#     "description": "Deepki is a global leader in ESG (Environmental, Social, and Governance) solutions for the real estate industry. We help maximize the value of your real estate portfolio by guiding you through the transition to a more sustainable and environmentally friendly approach. With our comprehensive solutions, we monitor millions of square meters across multiple countries, detecting and achieving significant CO\u2082 emission savings. Our mission is to preserve the planet by making real estate more virtuous. Join our community of environmentally conscious real estate professionals and let us help you make a positive impact. Contact us for more information.",
#     "sector_challenge": [
#       "Adapting to and mitigating the effects of climate change",
#       "Complying with evolving ESG regulations and standards",
#       "Integrating sustainable practices into existing real estate portfolios",
#       "Balancing profitability with environmental and social responsibilities",
#       "Measuring and reporting on ESG performance accurately"
#     ],
#     "innovation_challenge": [
#       "Developing advanced analytics to monitor and manage ESG metrics",
#       "Creating scalable solutions for CO\u2082 emission reduction in real estate",
#       "Innovating in green building materials and construction techniques",
#       "Implementing IoT and smart technologies for energy efficiency",
#       "Engaging stakeholders in sustainability initiatives"
#     ]
#   }
# }
# Enriching:  Electra
# With URL:  https://www.go-electra.com/fr/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Electra is a company that provides fast charging stations for electric vehicles. With their revolutionary experience, they aim to make recharging effortless and magical. Their stations are reservable, ensuring a stress-free experience. Electra offers the fastest charging on the market, allowing users to charge their vehicles in just 20 minutes for a range of 400km. They currently have 139 stations available and 103 stations in development. Electra's goal is to constantly improve the charging experience and prioritize customer satisfaction. They also offer partnership opportunities for businesses to host their charging stations and generate regular income.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:48:11.851893",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Energy, Utilities & Waste",
#     "business_model": "Service",
#     "end_buyer": "Consumer",
#     "client_focus": "B2B/B2C",
#     "description": "Electra is a company that provides fast charging stations for electric vehicles. With their revolutionary experience, they aim to make recharging effortless and magical. Their stations are reservable, ensuring a stress-free experience. Electra offers the fastest charging on the market, allowing users to charge their vehicles in just 20 minutes for a range of 400km. They currently have 139 stations available and 103 stations in development. Electra's goal is to constantly improve the charging experience and prioritize customer satisfaction. They also offer partnership opportunities for businesses to host their charging stations and generate regular income.",
#     "sector_challenge": [
#       "Infrastructure scalability to meet growing EV demand",
#       "Ensuring consistent and reliable power supply",
#       "Adapting to technological advancements and standards in EVs",
#       "Competition with other charging network providers",
#       "Navigating regulatory and environmental policies"
#     ],
#     "innovation_challenge": [
#       "Developing faster charging technologies",
#       "Creating a seamless user experience",
#       "Integrating smart and connected features",
#       "Maintaining cost-effectiveness while innovating",
#       "Expanding network intelligently to avoid oversaturation"
#     ]
#   }
# }
# Enriching:  Emotors
# With URL:  https://emotors.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Emotors is a company that specializes in providing e-Drive solutions for the car industry. They have expertise in all technical aspects of e-Drive development and are known for turning innovative technologies into competitive solutions for mass production. Emotors also offers career opportunities for individuals looking to challenge themselves and work in a creative and successful environment.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:48:36.472574",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Electronics",
#     "business_model": "Manufacturing",
#     "end_buyer": "Tech & Data",
#     "client_focus": "B2B",
#     "description": "Emotors is a company that specializes in providing e-Drive solutions for the car industry. They have expertise in all technical aspects of e-Drive development and are known for turning innovative technologies into competitive solutions for mass production. Emotors also offers career opportunities for individuals looking to challenge themselves and work in a creative and successful environment.",
#     "sector_challenge": [
#       "Transition to electric vehicles (EVs) and phasing out internal combustion engines",
#       "Meeting stringent environmental and emission regulations",
#       "High competition from established automotive manufacturers and new entrants",
#       "Supply chain issues for battery materials and electronic components",
#       "Balancing performance with cost and energy efficiency",
#       "Infrastructure development for EV charging"
#     ],
#     "innovation_challenge": [
#       "Developing more efficient and compact e-Drive systems",
#       "Reducing the cost of e-Drive components to make EVs more affordable",
#       "Improving energy density and longevity of batteries",
#       "Integrating advanced materials to enhance performance and reduce weight",
#       "Adapting to rapid changes in technology and consumer expectations",
#       "Ensuring scalability and flexibility in production for varying vehicle models"
#     ]
#   }
# }
# Enriching:  EPC Groupe
# With URL:  https://www.epc-groupe.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  EPC Groupe is a global leader in the manufacturing, storage, and distribution of explosives, particularly in the drilling and mining sector. With 125 years of experience, we provide effective solutions, technological innovations, and high-level services to clients in the mining, cement, aggregates, construction, and defense industries. Our comprehensive range of commercial explosives and customized services are known for their efficiency, safety, and ethical standards. With EPC Groupe, you can expect the highest level of professionalism and expertise in this demanding industry.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:49:03.936948",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Miscellaneous Manufacturing",
#     "business_model": "Manufacturing",
#     "end_buyer": "Procurement",
#     "client_focus": "B2B",
#     "description": "EPC Groupe is a global leader in the manufacturing, storage, and distribution of explosives, particularly in the drilling and mining sector. With 125 years of experience, we provide effective solutions, technological innovations, and high-level services to clients in the mining, cement, aggregates, construction, and defense industries. Our comprehensive range of commercial explosives and customized services are known for their efficiency, safety, and ethical standards. With EPC Groupe, you can expect the highest level of professionalism and expertise in this demanding industry.",
#     "sector_challenge": [
#       "Ensuring compliance with stringent regulations for the handling and transportation of explosives",
#       "Maintaining safety standards to prevent accidents and environmental harm",
#       "Adapting to fluctuating demand in mining and construction industries",
#       "Navigating geopolitical and economic uncertainties that can impact the supply of raw materials and the operation of global distribution networks"
#     ],
#     "innovation_challenge": [
#       "Developing more environmentally friendly explosives and sustainable mining practices",
#       "Integrating new technologies such as IoT and AI for improved precision in blasting and inventory management",
#       "Enhancing the efficiency and effectiveness of explosives to reduce costs and improve outcomes for clients",
#       "Staying ahead of the competition by continuously innovating in product development and service delivery"
#     ]
#   }
# }
# Enriching:  FAREVA AMBOISE
# With URL:  https://www.fareva.com/fr
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Fareva is a global leader in industrial outsourcing services. With over 41 international sites, we provide innovative and customized solutions in the industrial and household, beauty, pharmaceutical, and API sectors. Our expertise includes formulation, production, and packaging, catering to any production volume. Join our team in a dynamic and stimulating environment.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:49:30.839339",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Miscellaneous Manufacturing",
#     "business_model": "Manufacturing",
#     "end_buyer": "Procurement",
#     "client_focus": "B2B",
#     "description": "Fareva is a global leader in industrial outsourcing services. With over 41 international sites, we provide innovative and customized solutions in the industrial and household, beauty, pharmaceutical, and API sectors. Our expertise includes formulation, production, and packaging, catering to any production volume. Join our team in a dynamic and stimulating environment.",
#     "sector_challenge": [
#       "Maintaining quality and compliance across various regulatory environments",
#       "Adapting to rapid changes in consumer preferences and market demands",
#       "Ensuring supply chain resilience and sustainability",
#       "Navigating international trade policies and tariffs",
#       "Managing the complexity of operating across multiple sectors with different standards"
#     ],
#     "innovation_challenge": [
#       "Continuously improving and innovating in formulation and production processes",
#       "Integrating new technologies for more efficient production and packaging",
#       "Developing eco-friendly and sustainable solutions for industrial and household products",
#       "Staying ahead in the highly competitive beauty and pharmaceutical markets",
#       "Customizing solutions to meet the specific needs of a diverse client base"
#     ]
#   }
# }
# Enriching:  FLYING WHALES
# With URL:  https://www.flying-whales.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Flying Whales is a company revolutionizing air cargo transportation. They design a transport solution that aims to contribute to the economic development of remote regions and reduce the environmental impact of cargo transportation. They offer solutions in energy, humanitarian aid, industry and logistics, flying care, wood, and construction. Flying Whales consists of Flying Whales Industry, a manufacturer, and Flying Whales Services, an airline and airport company. They have three production sites. The company is committed to environmental and social responsibility. They have recent news and career opportunities available.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:49:56.816396",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Freight & Logistics",
#     "business_model": "Manufacturing",
#     "end_buyer": "Procurement",
#     "client_focus": "B2B",
#     "description": "Flying Whales is a company revolutionizing air cargo transportation. They design a transport solution that aims to contribute to the economic development of remote regions and reduce the environmental impact of cargo transportation. They offer solutions in energy, humanitarian aid, industry and logistics, flying care, wood, and construction. Flying Whales consists of Flying Whales Industry, a manufacturer, and Flying Whales Services, an airline and airport company. They have three production sites. The company is committed to environmental and social responsibility. They have recent news and career opportunities available.",
#     "sector_challenge": [
#       "Competition with established air cargo transportation companies",
#       "Regulatory compliance for aviation and environmental standards",
#       "Infrastructure development in remote regions",
#       "Balancing cost-efficiency with environmental sustainability",
#       "Adapting to fluctuating fuel prices and economic conditions"
#     ],
#     "innovation_challenge": [
#       "Developing energy-efficient and eco-friendly transportation technologies",
#       "Creating a scalable and flexible transport solution for diverse cargo types",
#       "Ensuring the reliability and safety of new air cargo solutions",
#       "Integrating with existing logistics and supply chain systems",
#       "Attracting skilled workforce for manufacturing and service operations"
#     ]
#   }
# }
# Enriching:  GILBERT
# With URL:  https://www.labogilbert.fr/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Laboratoires Gilbert is a French pharmaceutical and cosmetic company that offers health and wellness solutions for the whole family. They specialize in the health of babies and infant nutrition, respiratory and ENT (ear, nose, and throat) care, natural health products, and family pharmacy essentials. With a focus on research and development, innovation, and safety, their products are widely used in hospitals and pharmacies in France and around the world.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:50:27.089279",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Healthcare",
#     "business_model": "Manufacturing",
#     "end_buyer": "Consumer",
#     "client_focus": "B2B/B2C",
#     "description": "Laboratoires Gilbert is a French pharmaceutical and cosmetic company that offers health and wellness solutions for the whole family. They specialize in the health of babies and infant nutrition, respiratory and ENT (ear, nose, and throat) care, natural health products, and family pharmacy essentials. With a focus on research and development, innovation, and safety, their products are widely used in hospitals and pharmacies in France and around the world.",
#     "sector_challenge": [
#       "Regulatory compliance with global pharmaceutical standards",
#       "Adapting to rapid changes in healthcare demands and practices",
#       "Ensuring product safety and efficacy while scaling up production",
#       "Competition with larger pharmaceutical companies and generic drug producers",
#       "Navigating the complexities of global supply chains for raw materials and distribution"
#     ],
#     "innovation_challenge": [
#       "Developing new and effective formulations for baby and infant nutrition",
#       "Creating advanced respiratory and ENT care solutions that stand out in the market",
#       "Incorporating natural and sustainable ingredients into health products",
#       "Balancing innovation with cost-effectiveness to remain competitive",
#       "Investing in R&D while ensuring a quick turnaround time for product development"
#     ]
#   }
# }
# Enriching:  Groupe intuis
# With URL:  https://www.intuis.fr
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Intuis is an expert in heat pumps and radiators for thermal comfort. They offer a range of products including electric radiators, heat pumps, and connected heating solutions. Intuis provides advice and tailored products for replacing boilers, installing heat pumps, and replacing or installing electric radiators. They also have a network of 2500 installers available for implementation and maintenance services. Intuis focuses on developing reliable and innovative products that align with responsible consumption.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:50:49.453741",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Energy, Utilities & Waste",
#     "business_model": "Manufacturing",
#     "end_buyer": "Consumer",
#     "client_focus": "B2C",
#     "description": "Intuis is an expert in heat pumps and radiators for thermal comfort. They offer a range of products including electric radiators, heat pumps, and connected heating solutions. Intuis provides advice and tailored products for replacing boilers, installing heat pumps, and replacing or installing electric radiators. They also have a network of 2500 installers available for implementation and maintenance services. Intuis focuses on developing reliable and innovative products that align with responsible consumption.",
#     "sector_challenge": [
#       "Compliance with increasingly stringent energy efficiency and environmental regulations",
#       "Adaptation to the fluctuating costs and availability of raw materials",
#       "Integration of renewable energy sources",
#       "Meeting diverse customer needs for thermal comfort in various climates",
#       "Competition with other heating and cooling solution providers"
#     ],
#     "innovation_challenge": [
#       "Developing cost-effective and energy-efficient heat pump technologies",
#       "Creating smart connected heating solutions that are user-friendly",
#       "Ensuring product reliability and longevity in diverse environmental conditions",
#       "Incorporating sustainable materials and practices in product design and manufacturing",
#       "Staying ahead of technological advancements in the heating and cooling industry"
#     ]
#   }
# }
# Enriching:  Groupe Pilote
# With URL:  https://groupe-pilote.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Groupe Pilote is a French company that has been manufacturing recreational vehicles since 1962. They design products and services that cater to the dreams of freedom for individuals. With a focus on innovation, they develop high-tech solutions through their 7 complementary brands to meet the needs of their customers in France and internationally.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:51:11.423750",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Miscellaneous Manufacturing",
#     "business_model": "Manufacturing",
#     "end_buyer": "Consumer",
#     "client_focus": "B2C",
#     "description": "Groupe Pilote is a French company that has been manufacturing recreational vehicles since 1962. They design products and services that cater to the dreams of freedom for individuals. With a focus on innovation, they develop high-tech solutions through their 7 complementary brands to meet the needs of their customers in France and internationally.",
#     "sector_challenge": [
#       "Regulatory compliance with environmental standards",
#       "Adapting to fluctuating consumer travel preferences",
#       "Supply chain management for diverse components",
#       "International market competition and localization",
#       "Economic sensitivity to discretionary spending"
#     ],
#     "innovation_challenge": [
#       "Integrating sustainable and eco-friendly materials",
#       "Developing advanced safety features",
#       "Incorporating smart technology and connectivity",
#       "Enhancing energy efficiency of vehicles",
#       "Creating versatile and modular interior designs"
#     ]
#   }
# }
# Enriching:  IGL
# With URL:  https://igl-group.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  IGL is a company dedicated to organ preservation for transplantation. We provide advanced technologies to transplant teams worldwide, offering patients with end-stage chronic diseases the opportunity to be treated with transplantation. Our products, such as the RM4 renal perfusion system, support the monitoring and preservation of organs. With a high success rate and recognized efficiency, we have helped cure 70,000 patients through transplantation. Our technologies are available in over 300 medical centers globally. For more information, news, or to contact us, please visit our website.
#
# {
#   "metadata": {
#     "timestamp": "2023-12-05 15:51:38.195556",
#     "source": "industryGPT"
#   },
#   "company_profile": {
#     "website": null,
#     "business_status": null,
#     "industry": "Medical Devices & Equipment",
#     "business_model": "Manufacturing",
#     "end_buyer": "Tech & Data",
#     "client_focus": "B2B",
#     "description": "IGL is a company dedicated to organ preservation for transplantation. We provide advanced technologies to transplant teams worldwide, offering patients with end-stage chronic diseases the opportunity to be treated with transplantation. Our products, such as the RM4 renal perfusion system, support the monitoring and preservation of organs. With a high success rate and recognized efficiency, we have helped cure 70,000 patients through transplantation. Our technologies are available in over 300 medical centers globally. For more information, news, or to contact us, please visit our website.",
#     "sector_challenge": [
#       "Ensuring a consistent supply of donor organs to meet demand",
#       "Maintaining organ viability during preservation and transport",
#       "Complying with stringent regulatory standards for medical devices",
#       "Adapting to rapid changes in medical technology and transplantation techniques",
#       "Addressing ethical considerations in organ transplantation"
#     ],
#     "innovation_challenge": [
#       "Developing more advanced organ preservation systems to extend viability",
#       "Improving success rates of transplantation through technological innovation",
#       "Creating cost-effective solutions to make transplantation more accessible",
#       "Integrating new monitoring technologies to assess organ health in real-time",
#       "Researching and implementing methods to reduce organ rejection rates"
#     ]
#   }
# }
