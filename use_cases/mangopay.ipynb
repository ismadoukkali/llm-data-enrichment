# %% [markdown]
# ### industryGPT - Client MangoPay
#
# This is a python notebook to illustrate the system used for client MangoPay to classify potential prospect companies. The way to do this is by enriching the basic set of useful data points to filter potential target accounts.
#
# Here is the data points enriched in this specific demo:
# - **Platform Classification**: Classify within a predefined set of types of platforms.
# - **Client Focus**: Subset of customer business models does the company target.

# %% [markdown]
# #### Import Libraries

# %%
from openai import OpenAI
from bs4 import BeautifulSoup
import json
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from zenrows import ZenRowsClient
import os.path
import requests

# %% [markdown]
# #### OpenAI functions

# %%
client = OpenAI()

def generate_response(prompt):
    response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_feedback(initial_question, system_answer, feedback):
    response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(initial_question)},
        {"role": "system", "content": str(system_answer)},
        {"role": "user", "content": str(feedback)}
    ],
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_gpt3(prompt):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    max_tokens=1000,
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_gpt3_json(prompt):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    max_tokens=1000,
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

# %% [markdown]
# #### Retrieve HTML

# %%
def retrieve_html(url):
    client = ZenRowsClient("9fd8cbf3ac82dc40ade5d731997880b9e4561a32")

    params = {"block_resources": "image,media,font"}

    try:
        response = client.get(url, params=params)
    
    except Exception:
        params = {
            "block_resources": "image,media,font",
            "premium_proxy":"true",
            "resolve_captcha": "true"
            }

    soup = BeautifulSoup(response.text, "html.parser")

    # Process the HTML as before
    for script in soup(["script", "style"]):
        script.extract()

    text = soup.get_text()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)

    return text

# %% [markdown]
# #### Google search query

# %%
def selenium_search(query):
    # Replace these with your own API key and Custom Search Engine ID
    API_KEY = os.environ['GOOGLE_SEARCH_API_KEY']
    SEARCH_ENGINE_ID = os.environ['SEARCH_ENGINE_ID']

    # Base URL for Google Custom Search
    url = 'https://www.googleapis.com/customsearch/v1'

    # Parameters for the search
    params = {
        'key': API_KEY,
        'cx': SEARCH_ENGINE_ID,
        'q': query
    }

    # Send the GET request
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        results = response.json()
        # Return the first search result
        if 'items' in results:
            return results['items'][0]['link']
        else:
            return 'No results found'
    else:
        return f'Error: {response.status_code}'

# %% [markdown]
# #### Client focus prompt

# %%
# Client focus prompt
clients_focus = ["B2C", "B2B", "C2C", "B2B/B2C"]
prompt_client_focus = """

You are given the description of a company retrieved from it's website.

You will need to categorize the company within a Client Focus according to the taxonomy below.

There can only be ONE client focus. The answer needs to be concise and only can follow the taxonomy.

DO NOT come up with any taxonomy. STICK to the taxonomy below. 

Give your results in the format JSON  - 

'client_focus': [client focus] 


Here the taxonomy for the client focus:
B2C
B2B
C2C
B2B/B2C

Here a decription for each category:
B2C : Business to Consumer Model

B2B : Business to Business Model

C2C : Customer to Customer

B2B/B2C : Both Business to Business and Business to Consumer

"""

# %% [markdown]
# #### Platform Prompt

# %%
platform_tags = ["On-demand Platform", "Financial Platforms", "Product Marketplace", "Not Classified"]

prompt_marketplace = """
You are given the description of a company retrieved from a company's website.

You will need to categorize the company within an format of sales category according to the taxonomy below.

"On-demand platform" or "Product Marketplace" or "Financial Platforms" or ""Not Classified"

- Product Marketplace: A virtual commerce space where multiple vendors list and sell tangible goods to consumers or businesses. This can include marketplaces with a broad variety of products or niche sites specializing in specific categories, such as crafts or luxury watches. 
Examples include Amazon (general marketplace), Vinted (second-hand clothes), Etsy (handmade and vintage items), Chrono24 (luxury watches), Farfetch (fashion), Decathlon (sports equipment), Vestas (wind turbines), and Houzz (home remodeling and interior design).

- Financial Platforms: Digital systems supporting monetary services, including traditional banking, investment, lending, crowdfunding, insurtech, and innovative financial solutions. 
Any application that involves financial operations as their main point of focus should be classified here.
These platforms may offer personal and commercial banking products, investment opportunities, insurance policies, and technologies that facilitate financial transactions. 
Examples encompass Seedrs (equity crowdfunding), Ulule (crowdfunding), Homunity.com (real estate crowdfunding), Klarna (buy now, pay later services), Allianz (insurance), Lloyds Bank (banking), Alma (payment solutions), and Revolut (digital banking).

- On-Demand Platforms: Interactive, often mobile-accessible applications or websites that connect users with providers delivering immediate services across various sectors such as transportation, manufacturing, food delivery, home services, real estate and wellness. 
These platforms usually facilitate transactions and scheduling between the customer and service provider in real time. The service provider can be the company itself too. Examples include Deliveroo (food delivery), Uber (ride-hailing and food delivery), TaskRabbit (handyman and errand services), BlaBlaCar (carpooling), Treatwell (beauty and wellness bookings), and Cargo.one (air cargo services).

- Not Classified: Entities that do not align with the aforementioned categories. This includes organizations whose core operations do not revolve around selling products, providing financial services, connecting service providers with consumers in an on-demand fashion. 

There can only be ONE category. The answer needs to be concise and only can follow the taxonomy.

DO NOT come up with any taxonomy. STICK to the taxonomy below. 

Give your results in the format format JSON - 

'platform_tag': "On-demand Platform" or "Financial Platforms" or "Product Marketplace" or "Not Classified"

"""

# %%
# Company description prompt
organize_prompt = '''From the following scrapped text of a website explain what the business does. The text will be poorly written so take that in mind. 
Write everything in third person naming the company. Output only a description using key words of the industry. Focus on understanding what their business model is and how they operate. 

Here the scrapped code/text: '''

header_url= "Here the description of the company deducted from their website: "

# %%
# Helper functions
def truncate_string(input_string):
    if len(input_string) <= 3000:
        return input_string
    else:
        return input_string[:3000]

def format_url(url):
    if url.startswith("http://www."):
        url = url.replace("http://www.", "https://www.")
    elif url.startswith("http://"):
        url = url.replace("http://", "https://www.")
    elif url.startswith("www."):
        url = "https://" + url
    elif not url.startswith("https://"):
        url = "https://www." + url
    return url

# %%
# IndustryGPT 
exec = ThreadPoolExecutor(12)

def industryGPT(name, url, index):
    print('Enriching: ', name)
    print('With URL: ', url)

    full_response = {
            "index": index,
            "company_profile": {
                "name": str(name),
                "website": str(url),
                "client_focus": None,
                "platform_tag": None,
                "description": None
            }

        }
    
    try:
        url_text = retrieve_html(format_url(url))
        scrapped_code = url_text
        print('\n-> Retrieved text from website...')
    except Exception as e:
        print('Unaccessible URL as per error ->', e)
        print('Searching from Google.')
        new_url = selenium_search(format_url(url))
        url_text = retrieve_html(format_url(new_url))

    if len(url_text) > 30:
        print('-> Crafting company description...')
        description_openai = generate_response_gpt3(organize_prompt + truncate_string(url_text))
        print('\nDescription of the company: ', description_openai)

    else:
        print('Scrapped website or extra descriptors have less than 100 characters...')
        print('Trying to search on google a new page...')
        new_url = selenium_search(format_url(url))
        url_text = retrieve_html(new_url)
        description_openai = generate_response_gpt3(organize_prompt + truncate_string(url_text))
        print('\nDescription of the company: ', description_openai)
    
    # Save description
    full_response["company_profile"]["description"] = description_openai

    # Categorise industry & business Model
    response_marketplace = exec.submit(generate_response, (prompt_marketplace +
                                header_url +
                                description_openai))
    
    # Categorise client Focus
    response_clientfocus = exec.submit(generate_response, (prompt_client_focus +
                                header_url +
                                description_openai))
    
    result_clientfocus = response_clientfocus.result()
    result_marketplace = response_marketplace.result()

    # Is the categorization correct for client focus? 
    response_dict_clientfocus = json.loads(result_clientfocus)
    client_focus = response_dict_clientfocus["client_focus"]

    tries_client_focus = 0
    while client_focus not in clients_focus and tries_client_focus < 2:
        if tries_client_focus >= 2:
            print('Client focus not in category.')
            print('GPT failed twice, returning NaN in Client focus.')
            client_focus = None
            break
        
        print('Client Focus not in category.')
        print('Faulty Client Focus: ', client_focus)
        initial_question = (prompt_client_focus+ header_url + description_openai)
        system_answer = "Client Focus: " + client_focus
        feedback = "The client focus is not within taxonomy... retry please and stay within the provided taxonomy."
        # Resubmit the prompt
        retry_clientfocus = exec.submit(generate_response_feedback, initial_question, system_answer, feedback)
        retry_clientfocus_dict = retry_clientfocus.result()
        retry_clientfocus_dict_json = json.loads(retry_clientfocus_dict)
        client_focus = retry_clientfocus_dict_json["client_focus"]
        tries_client_focus += 1
    
    # Save result client_focus
    full_response["company_profile"]["client_focus"] = client_focus  
    

    response_dict_clientfocus = json.loads(result_marketplace)
    platform_tag = response_dict_clientfocus["platform_tag"]
    tries_marketplace = 0

    while platform_tag not in platform_tags and tries_marketplace < 2:
        if tries_marketplace >= 2:
            print('Platform tag not in category.')
            print('GPT failed twice, returning NaN in Client focus.')
            platform_tag = None
            break
        
        print('Platform tag not in category.')
        print('Faulty Platform tag: ', platform_tag)
        initial_question = (prompt_marketplace+ header_url + description_openai)
        system_answer = "Platform tag: " + platform_tag
        feedback = "The categorisation is not within taxonomy... retry please and stay within the provided taxonomy."
        # Resubmit the prompt
        retry_platform = exec.submit(generate_response_feedback, initial_question, system_answer, feedback)
        retry_platform_dict = retry_platform.result()
        retry_platform_dict_json = json.loads(retry_platform_dict)
        platform_tag = retry_platform_dict_json["platform_tag"]
        tries_marketplace += 1

    full_response["company_profile"]["platform_tag"] = platform_tag
    full_response_json = json.dumps(full_response)
    json_string_pretty = json.dumps(full_response, indent=2)
    print('')
    print(json_string_pretty)
    print('--------------------------------')

    return full_response_json

# %% [markdown]
# #### Demo for MangoPay

# %%
# industryGPT('Mano Mano', 'cargo.one')

# %% [markdown]
# #### CSV enrichment

# %%
df = pd.read_csv('MangoPay - Enrichment - Sheet1.csv')
df.columns
df.dropna(how='all', inplace=True)

# %%
df
# Out:
#       id       company name                             website  \
# 0      9          Cargo One              https://www.cargo.one/
# 1     12           Laserhub               https://laserhub.com/
# 2     14              Merxu               https://merxu.com/pl/
# 3     15          Metalshub         https://www.metals-hub.com/
# 4     17            Ontruck          https://www.ontruck.com/en
# 5     18             Rooser              https://www.rooser.eu/
# 6     21         Storefront      https://www.thestorefront.com/
# 7     24  Container xChange  https://www.container-xchange.com/
# 8     33         Ankorstore         https://www.ankorstore.com/
# 9     36              Twine              https://www.twine.net/
# 10    67            Creoate            https://www.creoate.com/
# 11    71              Upway                   https://upway.fr/
# 12    80          Playtomic               https://playtomic.io/
# 13    81            Electra      https://www.go-electra.com/en/
# 14    82           Twickets     https://www.twickets.live/en/uk
# 15   105              2trde              https://www.2trde.com/
# 16   116             Cabify               https://cabify.com/en
# 17   202         PromoFarma         https://www.promofarma.com/
# 18   255            Comatch            https://www.comatch.com/
# 19   257   Creative Fabrica    https://www.creativefabrica.com/
# 20   293             Qogita             https://www.qogita.com/
# 21   302          spotahome          https://www.spotahome.com/
# 22   303         spotAwheel         https://www.spotawheel.com/
# 23   306           Tradebay                https://tradebay.co/
# 24   313              Vivla              https://www.vivla.com/
# 25   314             Vosbor             https://www.vosbor.com/
# 26   317           Yardlink               https://yardlink.com/
# 27   356            Surplex         https://www.surplex.com/en/
# 28   374            Sennder          https://www.sennder.com/pl
# 29   376        Tracktor.fr                https://tracktor.fr/
# 30   378             e-farm              https://e-farm.com/pl/
# 31   801           Fractory               https://fractory.com/
# 32   802             Geomiq                 https://geomiq.com/
# 33   803           Kreatize           https://www.kreatize.com/
# 34   815             Worcon            https://www.wor-con.com/
# 35   837        Opendesk.cc            https://www.opendesk.cc/
# 36   848               Bark         https://www.bark.com/en/gb/
# 37   855              Comet         https://www.comet.co/en-us/
# 38   894           YunoJuno           https://www.yunojuno.com/
# 39   895             Zenjob          https://www.zenjob.com/de/
# 40   929             Rentuu   https://www.rentuu.com/pages/saas
# 41   944          Hirespace              https://hirespace.com/
# 42   969           Searates           https://www.searates.com/
# 43  1066           Metcycle                https://metycle.com/
# 44  1068           Boxxport           https://www.boxxport.com/
# 45  1285             Housfy                 https://housfy.com/
# 46  1303               Finn          https://www.finn.com/de-DE
# 47  1360      Native Spaces      https://www.native-spaces.com/
# 48  1366             xnomad             https://xnomad.co/en-eu
# 49  1449             Gigstr             https://www.gigstr.com/
# 50  1491         Flatlooker         https://www.flatlooker.com/
# 51  1495        Perfectstay   https://www.perfectstay.com/fr-FR
# 52  1496             Smiler                https://smiler.co/en
# 53  1497           Konfetti       https://gokonfetti.com/de-de/
# 54  1499               Raus              https://www.raus.life/
# 55  1509        appear here       https://www.appearhere.co.uk/
# 56  1517             Nautal             https://www.nautal.com/
# 57  1518              Zizoo              https://www.zizoo.com/
# 58  1543           Flatfair             https://flatfair.co.uk/
#
#                    domain                       R-website_url       S-Country
# 0               cargo.one                http://www.cargo.one         Germany
# 1            laserhub.com               https://laserhub.com/         Germany
# 2               merxu.com                  https://merxu.com/          Poland
# 3          metals-hub.com          https://www.metals-hub.com         Germany
# 4             ontruck.com                  http://ontruck.com           Spain
# 5               rooser.eu                  https://rooser.eu/  United Kingdom
# 6       thestorefront.com      https://www.thestorefront.com/          France
# 7   container-xchange.com  https://www.container-xchange.com/         Germany
# 8          ankorstore.com         https://www.ankorstore.com/          France
# 9               twine.net                    http://twine.net  United Kingdom
# 10            creoate.com            https://www.creoate.com/  United Kingdom
# 11               upway.fr                     http://upway.nl          France
# 12           playtomic.io               https://playtomic.io/           Spain
# 13         go-electra.com         https://www.go-electra.com/          France
# 14          twickets.live                http://twickets.live  United Kingdom
# 15              2trde.com               https://www.2trde.com         Germany
# 16             cabify.com                   http://cabify.com           Spain
# 17         promofarma.com          http://www.promofarma.com/           Spain
# 18            comatch.com  https://www.malt.uk/c/maltstrategy         Germany
# 19    creativefabrica.com    https://www.creativefabrica.com/     Netherlands
# 20             qogita.com             https://www.qogita.com/  United Kingdom
# 21          spotahome.com           https://www.spotahome.com           Spain
# 22         spotawheel.com         https://www.spotawheel.com/          Greece
# 23            tradebay.co                https://tradebay.co/          Sweden
# 24              vivla.com              https://www.vivla.com/           Spain
# 25             vosbor.com                   http://vosbor.com     Netherlands
# 26           yardlink.com               https://yardlink.com/  United Kingdom
# 27            surplex.com              http://www.surplex.com         Germany
# 28            sennder.com            https://www.sennder.com/         Germany
# 29            tracktor.fr                https://tracktor.fr/          France
# 30             e-farm.com               http://www.e-farm.com         Germany
# 31           fractory.com               https://fractory.com/  United Kingdom
# 32             geomiq.com                 https://geomiq.com/  United Kingdom
# 33           kreatize.com               https://kreatize.com/         Germany
# 34            wor-con.com            https://www.wor-con.com/         Croatia
# 35            opendesk.cc            https://www.opendesk.cc/  United Kingdom
# 36               bark.com         https://www.bark.com/en/gb/  United Kingdom
# 37               comet.co                https://www.comet.co          France
# 38           yunojuno.com                 http://yunojuno.com  United Kingdom
# 39             zenjob.com                  https://zenjob.de/         Germany
# 40             rentuu.com                   http://rentuu.com  United Kingdom
# 41          hirespace.com                http://hirespace.com  United Kingdom
# 42           searates.com             http://www.searates.com  United Kingdom
# 43            metycle.com                 https://METYCLE.com         Germany
# 44           boxxport.com                 http://boxxport.com         Germany
# 45             housfy.com                 https://housfy.com/           Spain
# 46               finn.com               https://www.finn.com/         Germany
# 47      native-spaces.com      https://www.native-spaces.com/          France
# 48              xnomad.co                    http://xnomad.co          Sweden
# 49             gigstr.com              https://www.gigstr.com          Sweden
# 50         flatlooker.com         https://www.flatlooker.com/          France
# 51        perfectstay.com     https://www.perfectstay.com/en/          France
# 52              smiler.co                   https://smiler.co     Netherlands
# 53         gokonfetti.com             https://gokonfetti.com/         Germany
# 54              raus.life                   https://raus.life         Germany
# 55       appearhere.co.uk         http://www.appearhere.co.uk  United Kingdom
# 56             nautal.com                   http://nautal.com           Spain
# 57              zizoo.com                    http://zizoo.com         Germany
# 58         flatfair.co.uk         https://www.flatfair.co.uk/  United Kingdom

# %%
def process_row(name, website, index):
    try:
        # Call the API and capture the response
        response = industryGPT(name, website, index)
        response_json = json.loads(response)


        # Extract the required data from response
        platform_tag = response_json['company_profile']['platform_tag']
        client_focus = response_json['company_profile']['client_focus']
        description = response_json['company_profile']['description']

        return index, platform_tag, client_focus, description
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        return index, None, None, None


df['Platform Tag'] = None
df['Client Focus'] = None
df['Description'] = None

executor = ThreadPoolExecutor(5)
# List to store futures
futures = []
for index, row in df.iterrows():
    name = row['company name']
    website = row['website'] 
    futures.append(executor.submit(process_row, name, website, index))

# Retrieve results and update DataFrame
for future in as_completed(futures):
    index, platform_tag, client_focus, description = future.result()
    df.at[index, 'Platform Tag'] = platform_tag
    df.at[index, 'Client Focus'] = client_focus
    df.at[index, 'Description'] = description
    df.to_csv('Enriched-MangoPay.csv')

# Shutdown the executor
executor.shutdown()
# Out:
# Enriching:  Cargo One
# With URL:  https://www.cargo.one/
# Enriching:  Laserhub
# With URL:  https://laserhub.com/
# Enriching:  Merxu
# With URL:  https://merxu.com/pl/
# Enriching:  Metalshub
# With URL:  https://www.metals-hub.com/
# Enriching:  Ontruck
# With URL:  https://www.ontruck.com/en
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Ontruck is a company that operates in the freight shipping and logistics industry. They provide transport services for pallets, packages, and parcels, ensuring that goods arrive safely and on time. They have developed AI-powered software that connects to management systems to solve road freight problems. This software includes an AI pricing engine, routing engine, predictive incident system, and forecast & capacity planner. Ontruck offers different service options for shippers, including Ontruck Economy, Ontruck Flex, and Ontruck Express, each with different pricing and delivery time options. They also have a network for carriers, allowing them to earn more by joining and utilizing their digitalized platform. Overall, Ontruck aims to optimize transport operations and provide smart transport solutions using their technology and network.
#
# Description of the company:  Metalshub is a leading supply chain solution and price intelligence platform in the metals and mining industry. They provide industry-specific software that assists in procurement and sales of raw materials. Their goal is to simplify and accelerate complex processes, bringing efficiency, transparency, and resilience to the global raw material supply chain. Metalshub aims to empower everyone in the industry to make data-driven decisions, reduce risks, and enhance productivity. They offer solutions for raw material buyers, producers, and suppliers, helping them generate cost savings, streamline processes, discover new customers, and unlock commercial value. Metalshub's digital tools enable users to reach potential customers and suppliers quickly, share data, and work at the speed of digital throughout the supply chain. They emphasize greater productivity, a powerful network, transparent ESG data, improved compliance, and data-driven decision-making. With over 200 raw materials traded on their platform, Metalshub is trusted by over 1,400 industry participants.
#
# {
#   "index": 4,
#   "company_profile": {
#     "name": "Ontruck",
#     "website": "https://www.ontruck.com/en",
#     "client_focus": "B2B",
#     "platform_tag": "On-demand Platform",
#     "description": "Ontruck is a company that operates in the freight shipping and logistics industry. They provide transport services for pallets, packages, and parcels, ensuring that goods arrive safely and on time. They have developed AI-powered software that connects to management systems to solve road freight problems. This software includes an AI pricing engine, routing engine, predictive incident system, and forecast & capacity planner. Ontruck offers different service options for shippers, including Ontruck Economy, Ontruck Flex, and Ontruck Express, each with different pricing and delivery time options. They also have a network for carriers, allowing them to earn more by joining and utilizing their digitalized platform. Overall, Ontruck aims to optimize transport operations and provide smart transport solutions using their technology and network."
#   }
# }
# --------------------------------
# Enriching:  Rooser
# With URL:  https://www.rooser.eu/
#
# {
#   "index": 3,
#   "company_profile": {
#     "name": "Metalshub",
#     "website": "https://www.metals-hub.com/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "Metalshub is a leading supply chain solution and price intelligence platform in the metals and mining industry. They provide industry-specific software that assists in procurement and sales of raw materials. Their goal is to simplify and accelerate complex processes, bringing efficiency, transparency, and resilience to the global raw material supply chain. Metalshub aims to empower everyone in the industry to make data-driven decisions, reduce risks, and enhance productivity. They offer solutions for raw material buyers, producers, and suppliers, helping them generate cost savings, streamline processes, discover new customers, and unlock commercial value. Metalshub's digital tools enable users to reach potential customers and suppliers quickly, share data, and work at the speed of digital throughout the supply chain. They emphasize greater productivity, a powerful network, transparent ESG data, improved compliance, and data-driven decision-making. With over 200 raw materials traded on their platform, Metalshub is trusted by over 1,400 industry participants."
#   }
# }
# --------------------------------
# Enriching:  Storefront
# With URL:  https://www.thestorefront.com/
#
# Description of the company:  Laserhub is a company that specializes in providing metal parts manufacturing services. They offer a range of processing methods including laser cutting, bending, CNC turning and milling, tube laser cutting, welding, deburring, threading, powder coating, galvanizing, and laser engraving. Laserhub works with various materials such as steel, stainless steel, aluminum, and copper. They have a platform where customers can access construction guidelines, receive support, become producers, and view prices and loyalty programs. Laserhub simplifies the entire process of requesting, ordering, and delivering metal parts through a digital platform. They provide instant quotes, handle the entire order processing, offer cost-effective solutions, and ensure delivery within 3 working days. With over 10,000 trusted customers, Laserhub offers reliable production networks and expert technical support.
#
# Description of the company:  The company, cargo.one, is an air freight platform that provides lightning-fast access to accurate rates for shipments, both exports and imports. They offer a full-fledged rate management system that combines the speed and flexibility of static rates with the accuracy of live rates. With cargo.one, users can get a real-time market overview within seconds to quote the right price. They also provide live agent rates for cross-trade and import shipments from over 30 countries, eliminating the need for numerous emails and hours of wait time.
#
# In addition to rate management, cargo.one offers the best end-to-end booking experience with the largest portfolio of airlines in the world. Users can easily book with just a couple of clicks, and if they don't have an Air Waybill (AWB), cargo.one provides one. The platform also allows users to modify or cancel bookings as needed. With 5,000 quality checks per search, cargo.one ensures that users can book what they see, providing the best offer quality and the highest booking acceptance rate in the industry.
#
# cargo.one also offers users their own digital storefront, allowing them to quote customers with live rates and enable instant booking confirmation. Users can add their charges to cargo.one's live airline rates and share quotes that customers can book directly. This eliminates the need for piecing together rate, route, and product information. Additionally, cargo.one allows partners to access rates anytime, helping users win new business by offering best-in-class service and listing rates to hundreds of agents searching on the platform.
#
# Lastly, cargo.one provides easy and intuitive analytics to help users benchmark their procurement performance against the market and identify opportunities. They also offer one-stop tracking, allowing users to track all their shipments in one place in real-time. Overall, cargo.one aims to provide a comprehensive solution for air freight management, offering efficient rate management, seamless booking, and valuable analytics and tracking capabilities to help businesses grow.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  merXu is a professional European online marketplace that facilitates B2B trade in the renewable energy sector. They connect verified buyers and sellers from across the European Union on an intuitive e-platform exclusively for businesses. They provide assistance in logistics, legal, and financial matters, simplifying the purchase and sale of professional products for utilizing renewable energy sources. Their goal is to help companies save time and money as they move towards a sustainable future. They offer a wide range of products in the renewable energy industry, including inverters, heat pumps, energy storage, photovoltaic modules, electric vehicle chargers, air conditioning, mounting elements, energy meters, optimizers, solar cables, and tools for electricians. They verify sellers to ensure access to the best products at competitive prices and offer a buyer protection program. Communication with suppliers from all EU countries is made easy through their real-time automatic translation feature. Customers can make purchases without waiting, pay online or defer payments, negotiate individual prices and terms with sellers, and submit inquiries to receive quotes and choose the best offers. merXu aims to provide a convenient and secure platform for international business transactions in the renewable energy sector.
#
# {
#   "index": 1,
#   "company_profile": {
#     "name": "Laserhub",
#     "website": "https://laserhub.com/",
#     "client_focus": "B2B",
#     "platform_tag": "On-demand Platform",
#     "description": "Laserhub is a company that specializes in providing metal parts manufacturing services. They offer a range of processing methods including laser cutting, bending, CNC turning and milling, tube laser cutting, welding, deburring, threading, powder coating, galvanizing, and laser engraving. Laserhub works with various materials such as steel, stainless steel, aluminum, and copper. They have a platform where customers can access construction guidelines, receive support, become producers, and view prices and loyalty programs. Laserhub simplifies the entire process of requesting, ordering, and delivering metal parts through a digital platform. They provide instant quotes, handle the entire order processing, offer cost-effective solutions, and ensure delivery within 3 working days. With over 10,000 trusted customers, Laserhub offers reliable production networks and expert technical support."
#   }
# }
# --------------------------------
# Enriching:  Container xChange
# With URL:  https://www.container-xchange.com/
#
# {
#   "index": 0,
#   "company_profile": {
#     "name": "Cargo One",
#     "website": "https://www.cargo.one/",
#     "client_focus": "B2B",
#     "platform_tag": "On-demand Platform",
#     "description": "The company, cargo.one, is an air freight platform that provides lightning-fast access to accurate rates for shipments, both exports and imports. They offer a full-fledged rate management system that combines the speed and flexibility of static rates with the accuracy of live rates. With cargo.one, users can get a real-time market overview within seconds to quote the right price. They also provide live agent rates for cross-trade and import shipments from over 30 countries, eliminating the need for numerous emails and hours of wait time. \n\nIn addition to rate management, cargo.one offers the best end-to-end booking experience with the largest portfolio of airlines in the world. Users can easily book with just a couple of clicks, and if they don't have an Air Waybill (AWB), cargo.one provides one. The platform also allows users to modify or cancel bookings as needed. With 5,000 quality checks per search, cargo.one ensures that users can book what they see, providing the best offer quality and the highest booking acceptance rate in the industry.\n\ncargo.one also offers users their own digital storefront, allowing them to quote customers with live rates and enable instant booking confirmation. Users can add their charges to cargo.one's live airline rates and share quotes that customers can book directly. This eliminates the need for piecing together rate, route, and product information. Additionally, cargo.one allows partners to access rates anytime, helping users win new business by offering best-in-class service and listing rates to hundreds of agents searching on the platform.\n\nLastly, cargo.one provides easy and intuitive analytics to help users benchmark their procurement performance against the market and identify opportunities. They also offer one-stop tracking, allowing users to track all their shipments in one place in real-time. Overall, cargo.one aims to provide a comprehensive solution for air freight management, offering efficient rate management, seamless booking, and valuable analytics and tracking capabilities to help businesses grow."
#   }
# }
# --------------------------------
# Enriching:  Ankorstore
# With URL:  https://www.ankorstore.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Rooser is an online marketplace that simplifies seafood trading. They connect wholesale buyers with seafood suppliers, providing a platform for buying and selling seafood with confidence. Rooser aims to remove the guesswork and frustrations of the seafood industry by offering a simple and transparent trading experience. Buyers can browse and order stock in real-time, negotiate prices, and access bulk volume offers. Suppliers can list their stock, share offers with buyers, and get paid on time. Rooser also ensures quality control and handles logistics connections to ensure timely delivery of orders. Overall, Rooser's business model revolves around facilitating seafood trading, providing a platform for buyers and suppliers to connect and trade seafood products.
#
# {
#   "index": 2,
#   "company_profile": {
#     "name": "Merxu",
#     "website": "https://merxu.com/pl/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "merXu is a professional European online marketplace that facilitates B2B trade in the renewable energy sector. They connect verified buyers and sellers from across the European Union on an intuitive e-platform exclusively for businesses. They provide assistance in logistics, legal, and financial matters, simplifying the purchase and sale of professional products for utilizing renewable energy sources. Their goal is to help companies save time and money as they move towards a sustainable future. They offer a wide range of products in the renewable energy industry, including inverters, heat pumps, energy storage, photovoltaic modules, electric vehicle chargers, air conditioning, mounting elements, energy meters, optimizers, solar cables, and tools for electricians. They verify sellers to ensure access to the best products at competitive prices and offer a buyer protection program. Communication with suppliers from all EU countries is made easy through their real-time automatic translation feature. Customers can make purchases without waiting, pay online or defer payments, negotiate individual prices and terms with sellers, and submit inquiries to receive quotes and choose the best offers. merXu aims to provide a convenient and secure platform for international business transactions in the renewable energy sector."
#   }
# }
# --------------------------------
# Enriching:  Twine
# With URL:  https://www.twine.net/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The company operates a platform that allows users to rent various types of spaces for events, pop-up stores, showrooms, and more. They offer a wide range of locations in major cities around the world, including New York, Paris, and London. Users can search for spaces based on their specific needs and duration, and book them for a day, week, month, or even longer. The company also offers a priority pass for customers who want to increase their chances of securing their desired space, which includes personalized space propositions, a dedicated account manager, and access to exclusive and offline spaces.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# {
#   "index": 5,
#   "company_profile": {
#     "name": "Rooser",
#     "website": "https://www.rooser.eu/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "Rooser is an online marketplace that simplifies seafood trading. They connect wholesale buyers with seafood suppliers, providing a platform for buying and selling seafood with confidence. Rooser aims to remove the guesswork and frustrations of the seafood industry by offering a simple and transparent trading experience. Buyers can browse and order stock in real-time, negotiate prices, and access bulk volume offers. Suppliers can list their stock, share offers with buyers, and get paid on time. Rooser also ensures quality control and handles logistics connections to ensure timely delivery of orders. Overall, Rooser's business model revolves around facilitating seafood trading, providing a platform for buyers and suppliers to connect and trade seafood products."
#   }
# }
# --------------------------------
# Enriching:  Creoate
# With URL:  https://www.creoate.com/
#
# Description of the company:  Ankorstore is a wholesale marketplace that serves as a platform for European brands to sell their products. They offer a wide range of products in various categories including home and kitchen, food and drinks, beauty and wellness, fashion and accessories, jewelry, baby and kids, stationery and hobbies. Customers can find items such as candles, cookware, furniture, home decor, linens, outdoor products, pet supplies, tableware, food and drinks, beauty and wellness products, and more. Ankorstore connects retailers with brands, allowing them to purchase products at wholesale prices for resale in their own stores.
#
# Description of the company:  The company, Twine, is a platform that connects businesses with expert freelancers in various industries. They offer a wide range of services including marketing, engineering, AI and machine learning, diversity and inclusion, and business and enterprise solutions. Businesses can post their projects or jobs for free and hire freelance specialists quickly. Twine's global network of freelancers allows for scalability and the ability to outsource work on a large scale. They also help companies build a more diverse and inclusive workforce by providing access to a wide range of skills and expertise.
#
# Description of the company:  Container xChange is an online platform for container logistics and operations. They bring together relevant companies to manage and book shipping containers, optimize invoicing and payments, and execute all related processes. They offer container trading and leasing services, allowing users to buy, sell, and lease containers globally. They have a marketplace with over 100,000 offers, providing transparency on market prices and dealing with 1500+ vetted partners. They also provide customer support and payment protection for all deals. Additionally, they offer insights and resources related to container logistics, such as research reports and a D&D calculator. They are trusted by 1500+ leading industry partners.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# {
#   "index": 9,
#   "company_profile": {
#     "name": "Twine",
#     "website": "https://www.twine.net/",
#     "client_focus": "B2B",
#     "platform_tag": "On-demand Platform",
#     "description": "The company, Twine, is a platform that connects businesses with expert freelancers in various industries. They offer a wide range of services including marketing, engineering, AI and machine learning, diversity and inclusion, and business and enterprise solutions. Businesses can post their projects or jobs for free and hire freelance specialists quickly. Twine's global network of freelancers allows for scalability and the ability to outsource work on a large scale. They also help companies build a more diverse and inclusive workforce by providing access to a wide range of skills and expertise."
#   }
# }
# --------------------------------
# Enriching:  Upway
# With URL:  https://upway.fr/
#
# {
#   "index": 8,
#   "company_profile": {
#     "name": "Ankorstore",
#     "website": "https://www.ankorstore.com/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "Ankorstore is a wholesale marketplace that serves as a platform for European brands to sell their products. They offer a wide range of products in various categories including home and kitchen, food and drinks, beauty and wellness, fashion and accessories, jewelry, baby and kids, stationery and hobbies. Customers can find items such as candles, cookware, furniture, home decor, linens, outdoor products, pet supplies, tableware, food and drinks, beauty and wellness products, and more. Ankorstore connects retailers with brands, allowing them to purchase products at wholesale prices for resale in their own stores."
#   }
# }
# --------------------------------
# Enriching:  Playtomic
# With URL:  https://playtomic.io/
#
# {
#   "index": 7,
#   "company_profile": {
#     "name": "Container xChange",
#     "website": "https://www.container-xchange.com/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "Container xChange is an online platform for container logistics and operations. They bring together relevant companies to manage and book shipping containers, optimize invoicing and payments, and execute all related processes. They offer container trading and leasing services, allowing users to buy, sell, and lease containers globally. They have a marketplace with over 100,000 offers, providing transparency on market prices and dealing with 1500+ vetted partners. They also provide customer support and payment protection for all deals. Additionally, they offer insights and resources related to container logistics, such as research reports and a D&D calculator. They are trusted by 1500+ leading industry partners."
#   }
# }
# --------------------------------
# Enriching:  Electra
# With URL:  https://www.go-electra.com/en/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Creoate is an online wholesale marketplace that connects independent retailers with independent brands. They provide a platform for retailers to source stock directly from brands without the traditional cost and hassle. Creoate does not hold stock, instead, when an order is placed through their website, the retailer is buying directly from the brand. They offer flexible payment options, including buy now pay later, and have a minimum order requirement set by each brand. Creoate also offers free global shipping for orders over £300 and easy returns. They currently ship to the UK, Europe, and the US.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# {
#   "index": 10,
#   "company_profile": {
#     "name": "Creoate",
#     "website": "https://www.creoate.com/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "Creoate is an online wholesale marketplace that connects independent retailers with independent brands. They provide a platform for retailers to source stock directly from brands without the traditional cost and hassle. Creoate does not hold stock, instead, when an order is placed through their website, the retailer is buying directly from the brand. They offer flexible payment options, including buy now pay later, and have a minimum order requirement set by each brand. Creoate also offers free global shipping for orders over \u00a3300 and easy returns. They currently ship to the UK, Europe, and the US."
#   }
# }
# --------------------------------
# Enriching:  Twickets
# With URL:  https://www.twickets.live/en/uk
#
# {
#   "index": 6,
#   "company_profile": {
#     "name": "Storefront",
#     "website": "https://www.thestorefront.com/",
#     "client_focus": "B2B/B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "The company operates a platform that allows users to rent various types of spaces for events, pop-up stores, showrooms, and more. They offer a wide range of locations in major cities around the world, including New York, Paris, and London. Users can search for spaces based on their specific needs and duration, and book them for a day, week, month, or even longer. The company also offers a priority pass for customers who want to increase their chances of securing their desired space, which includes personalized space propositions, a dedicated account manager, and access to exclusive and offline spaces."
#   }
# }
# --------------------------------
# Enriching:  2trde
# With URL:  https://www.2trde.com/
#
# Description of the company:  Upway is a company that specializes in reconditioned electric bicycles. They offer a wide range of electric bikes, including mountain bikes, city bikes, folding bikes, road bikes, cargo bikes, and more. They sell both new and discounted bikes, with prices ranging from less than 1000€ to over 2000€. Upway also offers accessories such as locks, bags, helmets, GPS trackers, and child seats. Their mission is to provide affordable electric bikes that are reconditioned by professionals and come with a one-year warranty. They provide guidance and information to help customers choose the right electric bike for their needs. Upway offers delivery services and a 14-day return policy.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The company, Electra, operates in the electric vehicle charging industry. They provide fast charging stations and offer a revolutionary charging experience. Users can download their app to easily access and use their charging stations. Electra aims to make vehicle charging more reliable and customer-centric. They prioritize the customer's time, energy, and peace of mind by delivering the fastest charging in the industry and creating a stress-free charging experience. Electra also offers opportunities for businesses to host their charging stations and generate new income without any cost or maintenance. They have a network of existing stations and are continuously expanding with stations in development. Overall, Electra's business model revolves around providing efficient and convenient electric vehicle charging solutions.
#
# {
#   "index": 11,
#   "company_profile": {
#     "name": "Upway",
#     "website": "https://upway.fr/",
#     "client_focus": "B2C",
#     "platform_tag": "Product Marketplace",
#     "description": "Upway is a company that specializes in reconditioned electric bicycles. They offer a wide range of electric bikes, including mountain bikes, city bikes, folding bikes, road bikes, cargo bikes, and more. They sell both new and discounted bikes, with prices ranging from less than 1000\u20ac to over 2000\u20ac. Upway also offers accessories such as locks, bags, helmets, GPS trackers, and child seats. Their mission is to provide affordable electric bikes that are reconditioned by professionals and come with a one-year warranty. They provide guidance and information to help customers choose the right electric bike for their needs. Upway offers delivery services and a 14-day return policy."
#   }
# }
# --------------------------------
# Enriching:  Cabify
# With URL:  https://cabify.com/en
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Twickets is a fan-to-fan ticket resale company that operates as a marketplace for live event tickets. They are the largest ticket resale site in the UK and their unique selling point is that they cap prices at face value (+fees). Users can buy and sell tickets for various events such as concerts, theater shows, and tours. The company ensures a trusted and secure platform for fans to exchange tickets with each other.
#
# {
#   "index": 13,
#   "company_profile": {
#     "name": "Electra",
#     "website": "https://www.go-electra.com/en/",
#     "client_focus": "B2B/B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "The company, Electra, operates in the electric vehicle charging industry. They provide fast charging stations and offer a revolutionary charging experience. Users can download their app to easily access and use their charging stations. Electra aims to make vehicle charging more reliable and customer-centric. They prioritize the customer's time, energy, and peace of mind by delivering the fastest charging in the industry and creating a stress-free charging experience. Electra also offers opportunities for businesses to host their charging stations and generate new income without any cost or maintenance. They have a network of existing stations and are continuously expanding with stations in development. Overall, Electra's business model revolves around providing efficient and convenient electric vehicle charging solutions."
#   }
# }
# --------------------------------
# Enriching:  PromoFarma
# With URL:  https://www.promofarma.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# {
#   "index": 14,
#   "company_profile": {
#     "name": "Twickets",
#     "website": "https://www.twickets.live/en/uk",
#     "client_focus": "C2C",
#     "platform_tag": "Product Marketplace",
#     "description": "Twickets is a fan-to-fan ticket resale company that operates as a marketplace for live event tickets. They are the largest ticket resale site in the UK and their unique selling point is that they cap prices at face value (+fees). Users can buy and sell tickets for various events such as concerts, theater shows, and tours. The company ensures a trusted and secure platform for fans to exchange tickets with each other."
#   }
# }
# --------------------------------
# Enriching:  Comatch
# With URL:  https://www.comatch.com/
#
# Description of the company:  Cabify is a transportation company that operates in multiple cities around the world. They offer ride-hailing services for both passengers and businesses. Cabify focuses on providing safer and higher quality rides by employing verified drivers, using geolocation technology, and offering a safety button for emergencies. They also prioritize transparency by showing the price upfront before the journey begins. In addition to passenger transportation, Cabify offers logistics solutions for companies, including storage and last-mile distribution. Overall, Cabify aims to provide a convenient and reliable transportation service while prioritizing safety and quality.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The company operates a multichannel platform for digital vehicle trading. They provide a service that allows users to auction their vehicles simultaneously on multiple auction houses, increasing the chances of finding the right buyer. The company offers efficient processes, a marketplace, and a single point of contact for vehicle intake, auction, pickup, and payment processing. They also utilize intelligent data enrichment to ensure faster processes and cleaner data, resulting in fewer complaints. Additionally, the company allows users to bring their own buyers while taking advantage of the benefits of digital auctions. Their platform aims to address the inefficiencies and high costs associated with traditional B2B vehicle marketing channels. By offering digital and efficient processes, they claim to reduce costs by an average of 65%. They also enable users to auction their vehicles on multiple auction houses, increasing bids and profits. The company aims to reduce capital binding by shortening the average auction duration from 30 days to 7 days. They also streamline the vehicle intake process, saving approximately 83% of the time spent by employees. Through smart data capture and enrichment, they provide more accurate vehicle information and automatically counteract complaints. The company offers a multichannel approach to vehicle trading, allowing users to leverage multiple channels for increased profitability.
#
# Description of the company:  Playtomic is a platform that helps users find and book sports facilities, specifically for racket sports such as Padel and Tennis. They provide a user-friendly application where users can search for nearby clubs, find equal level matches, and connect with teammates or rivals to play with. Playtomic also offers a player level estimation system to ensure competitive matches and improvement opportunities. They have a large community of over 1 million players, with access to more than 2,900 sports clubs and 12,700 courts and pitches across 1,500 cities. Users can easily book available courts and make secure payments through the app. Playtomic aims to make it easier for users to find and enjoy racket sports activities.
#
# Description of the company:  The company is an online platform that offers pharmacy, parapharmacy, and cosmetic products. They provide a wide range of products including medications, health and wellness items, cosmetics, hygiene products, dietetics, baby and maternity products, optical products, and orthopedic supplies. Customers can browse through different categories and make purchases online. The company also offers free shipping for orders above a certain amount and delivers to various countries. Customers can create an account, track their orders, and manage their personal information and preferences on the website.
#
# {
#   "index": 16,
#   "company_profile": {
#     "name": "Cabify",
#     "website": "https://cabify.com/en",
#     "client_focus": "B2B/B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "Cabify is a transportation company that operates in multiple cities around the world. They offer ride-hailing services for both passengers and businesses. Cabify focuses on providing safer and higher quality rides by employing verified drivers, using geolocation technology, and offering a safety button for emergencies. They also prioritize transparency by showing the price upfront before the journey begins. In addition to passenger transportation, Cabify offers logistics solutions for companies, including storage and last-mile distribution. Overall, Cabify aims to provide a convenient and reliable transportation service while prioritizing safety and quality."
#   }
# }
# --------------------------------
# Enriching:  Creative Fabrica
# With URL:  https://www.creativefabrica.com/
#
# {
#   "index": 15,
#   "company_profile": {
#     "name": "2trde",
#     "website": "https://www.2trde.com/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "The company operates a multichannel platform for digital vehicle trading. They provide a service that allows users to auction their vehicles simultaneously on multiple auction houses, increasing the chances of finding the right buyer. The company offers efficient processes, a marketplace, and a single point of contact for vehicle intake, auction, pickup, and payment processing. They also utilize intelligent data enrichment to ensure faster processes and cleaner data, resulting in fewer complaints. Additionally, the company allows users to bring their own buyers while taking advantage of the benefits of digital auctions. Their platform aims to address the inefficiencies and high costs associated with traditional B2B vehicle marketing channels. By offering digital and efficient processes, they claim to reduce costs by an average of 65%. They also enable users to auction their vehicles on multiple auction houses, increasing bids and profits. The company aims to reduce capital binding by shortening the average auction duration from 30 days to 7 days. They also streamline the vehicle intake process, saving approximately 83% of the time spent by employees. Through smart data capture and enrichment, they provide more accurate vehicle information and automatically counteract complaints. The company offers a multichannel approach to vehicle trading, allowing users to leverage multiple channels for increased profitability."
#   }
# }
# --------------------------------
# Enriching:  Qogita
# With URL:  https://www.qogita.com/
#
# {
#   "index": 12,
#   "company_profile": {
#     "name": "Playtomic",
#     "website": "https://playtomic.io/",
#     "client_focus": "B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "Playtomic is a platform that helps users find and book sports facilities, specifically for racket sports such as Padel and Tennis. They provide a user-friendly application where users can search for nearby clubs, find equal level matches, and connect with teammates or rivals to play with. Playtomic also offers a player level estimation system to ensure competitive matches and improvement opportunities. They have a large community of over 1 million players, with access to more than 2,900 sports clubs and 12,700 courts and pitches across 1,500 cities. Users can easily book available courts and make secure payments through the app. Playtomic aims to make it easier for users to find and enjoy racket sports activities."
#   }
# }
# --------------------------------
# Enriching:  spotahome
# With URL:  https://www.spotahome.com/
#
# Description of the company:  COMATCH is a curated marketplace for independent management consultants and industry experts. They provide a best-in-class matching service for organizations from all sectors. They work with leading companies and collaborate with the perfect team or individual based on their proven algorithm and extensive vetting process. They offer a wide range of capabilities, including management consultants, industry experts, digital experts, interim managers, and more. They have a global network of top-tier consultants and industry experts who have expertise in various fields such as consumer goods, automotive, pharma, IT services, and more. They have completed over 6,000 projects in 26 countries and have a high project evaluation score. They are trusted by 50% of the DAX-40 and CAC40 companies.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# {
#   "index": 18,
#   "company_profile": {
#     "name": "Comatch",
#     "website": "https://www.comatch.com/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
#     "description": "COMATCH is a curated marketplace for independent management consultants and industry experts. They provide a best-in-class matching service for organizations from all sectors. They work with leading companies and collaborate with the perfect team or individual based on their proven algorithm and extensive vetting process. They offer a wide range of capabilities, including management consultants, industry experts, digital experts, interim managers, and more. They have a global network of top-tier consultants and industry experts who have expertise in various fields such as consumer goods, automotive, pharma, IT services, and more. They have completed over 6,000 projects in 26 countries and have a high project evaluation score. They are trusted by 50% of the DAX-40 and CAC40 companies."
#   }
# }
# --------------------------------
# Enriching:  spotAwheel
# With URL:  https://www.spotawheel.com/
#
# {
#   "index": 17,
#   "company_profile": {
#     "name": "PromoFarma",
#     "website": "https://www.promofarma.com/",
#     "client_focus": "B2C",
#     "platform_tag": "Product Marketplace",
#     "description": "The company is an online platform that offers pharmacy, parapharmacy, and cosmetic products. They provide a wide range of products including medications, health and wellness items, cosmetics, hygiene products, dietetics, baby and maternity products, optical products, and orthopedic supplies. Customers can browse through different categories and make purchases online. The company also offers free shipping for orders above a certain amount and delivers to various countries. Customers can create an account, track their orders, and manage their personal information and preferences on the website."
#   }
# }
# --------------------------------
# Enriching:  Tradebay
# With URL:  https://tradebay.co/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The business, Creative Fabrica, operates in the industry of premium crafting fonts, graphics, and more. They offer a wide range of products including fonts, graphics, PNGs, illustrations, backgrounds, teaching materials, patterns, and more. They also provide various tools such as CF Spark, Fontcloud, Shapecloud, and Webfont Generator to assist users in creating their own designs. Additionally, they offer classes in areas such as Cricut, graphic design, illustrating, and printing & sublimation. The business model appears to be a subscription-based service, with options for unlimited access to fonts, graphics, and other resources. They also offer discounted deals and freebies to their customers.
#
# Description of the company:  The company, Spotahome, operates an online platform for renting apartment-flats and rooms on a short or long-term basis. They offer a wide range of accommodations including apartments, rooms in shared flats, studios, and student residences. The platform provides users with honest photographs, videos, and descriptions of each property to help them make safe decisions. Spotahome also verifies the properties and offers fraud protection to ensure a secure renting experience. They have a large inventory of over 120,000 fully-online rentals and work with over 13,000 active landlords. The company operates in various cities across Europe, including Madrid, Barcelona, Rome, Milan, Lisbon, Berlin, and more. They aim to provide an easy and reliable online renting experience for their customers.
#
# {
#   "index": 19,
#   "company_profile": {
#     "name": "Creative Fabrica",
#     "website": "https://www.creativefabrica.com/",
#     "client_focus": "B2C",
#     "platform_tag": "Product Marketplace",
#     "description": "The business, Creative Fabrica, operates in the industry of premium crafting fonts, graphics, and more. They offer a wide range of products including fonts, graphics, PNGs, illustrations, backgrounds, teaching materials, patterns, and more. They also provide various tools such as CF Spark, Fontcloud, Shapecloud, and Webfont Generator to assist users in creating their own designs. Additionally, they offer classes in areas such as Cricut, graphic design, illustrating, and printing & sublimation. The business model appears to be a subscription-based service, with options for unlimited access to fonts, graphics, and other resources. They also offer discounted deals and freebies to their customers."
#   }
# }
# --------------------------------
# Enriching:  Vivla
# With URL:  https://www.vivla.com/
#
# Description of the company:  Qogita is a one-stop wholesale marketplace for branded products. They connect thousands of suppliers with buyers, allowing them to save time and money. Qogita offers a catalog of over 150,000 SKUs and €500M+ worth of stock from 200+ sellers in Europe. Their products are competitively priced and ready to ship in a few days. Qogita's business model revolves around providing a seamless procurement process for buyers. They use cutting-edge technology to find the best available prices for all desired items and present them in a single, organized cart. Buyers can then choose how and when to pay, allowing them to focus on selling while Qogita takes care of everything else. Qogita aims to help small businesses compete with larger companies by streamlining the procurement process and offering a wide range of products at competitive prices.
#
# Description of the company:  TradeBay is a B2B marketplace that connects wholesale buyers and sellers in the global fruit trading community. Their platform enables safer and more efficient trade by providing a network of trusted partners, access to new markets, and secure online trading capabilities. Sellers, buyers, and traders can browse for goods, negotiate deals, and write agreements in real-time. TradeBay also offers a tailored financing solution to bridge insecurities and mediate payment terms, helping with financing and insurance. Their services include an extended network to discover new markets, tailored financing solutions for specific requirements, and the ability to list sudden excess or deficits in production or supply. Overall, TradeBay aims to facilitate global trade in the fruit industry by providing a comprehensive online marketplace and supporting services.
#
# Description of the company:  Spotawheel.com is a fast-growing used cars platform in Europe. They aim to change the way people buy used cars by providing a reliable and transparent car buying experience. They use efficient and customer-centric proprietary technology to empower people in purchasing a reliable car. Spotawheel pre-inspects all the cars listed on their platform, ensuring they are accident-free and inspected for mechanical issues and real kilometers. They provide detailed inspection reports, high-quality photos, videos, 360 captures, and extended information to help customers make informed decisions. Customers can choose between a test drive delivered to their doorstep or a touchless way to buy their next car, with the option of getting covered with up to 5 years warranty. Spotawheel is powered by the most accurate mechanical inspection in Europe, with a low error rate. They have a team of exceptional people who are dedicated to challenging and changing the used car industry to deliver amazing experiences for their customers. Spotawheel operates in multiple countries and has job openings available. Their customers have expressed satisfaction with their services, praising the quality of the cars and the friendly and competent service provided by Spotawheel.
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# {
#   "index": 21,
#   "company_profile": {
#     "name": "spotahome",
#     "website": "https://www.spotahome.com/",
#     "client_focus": "B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "The company, Spotahome, operates an online platform for renting apartment-flats and rooms on a short or long-term basis. They offer a wide range of accommodations including apartments, rooms in shared flats, studios, and student residences. The platform provides users with honest photographs, videos, and descriptions of each property to help them make safe decisions. Spotahome also verifies the properties and offers fraud protection to ensure a secure renting experience. They have a large inventory of over 120,000 fully-online rentals and work with over 13,000 active landlords. The company operates in various cities across Europe, including Madrid, Barcelona, Rome, Milan, Lisbon, Berlin, and more. They aim to provide an easy and reliable online renting experience for their customers."
#   }
# }
# --------------------------------
# Enriching:  Vosbor
# With URL:  https://www.vosbor.com/
#
# {
#   "index": 23,
#   "company_profile": {
#     "name": "Tradebay",
#     "website": "https://tradebay.co/",
#     "client_focus": "B2B",
#     "platform_tag": "Product Marketplace",
# ...
#   }
# }
# --------------------------------
# Enriching:  Raus
# With URL:  https://www.raus.life/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Flatlooker is a company that operates in the online apartment rental and property management industry. They provide a platform where users can visit and rent their next accommodation from the comfort of their own homes. Flatlooker offers a wide range of apartments for rent, which are inspected by experts to ensure they match the presented photos and videos. They have been in operation since 2016 and have already facilitated over 20,000 rentals. Their business model combines technology and real estate expertise to provide a fast and transparent service. For property owners, Flatlooker offers a team of experts and advanced technological approaches to accelerate the rental process. Users can easily find their dream accommodation by completing an online registration, conducting virtual tours, submitting applications, signing leases online, and having an expert from Flatlooker conduct the move-in inspection. Additionally, Flatlooker provides a dedicated manager to handle routine management requests through their application. The company has gained the trust of over 5,000 property owners and 20,000 tenants.
#
# -> Retrieved text from website...
# Scrapped website or extra descriptors have less than 100 characters...
# Trying to search on google a new page...
# Error processing row 54: 'GOOGLE_SEARCH_API_KEY'
# Enriching:  appear here
# With URL:  https://www.appearhere.co.uk/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The company offers courses, gift ideas, and team events. They have a wide range of over 4,000 courses and experiences available. They provide various activities such as pottery classes, cocktail making courses, wine tastings, and art workshops. They also offer gift vouchers for these experiences. Additionally, they specialize in organizing team events and provide assistance in planning and offering customized options. The company operates in multiple cities and offers courses in categories such as cooking, crafts, art, and more.
#
# {
#   "index": 50,
#   "company_profile": {
#     "name": "Flatlooker",
#     "website": "https://www.flatlooker.com/",
#     "client_focus": "B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "Flatlooker is a company that operates in the online apartment rental and property management industry. They provide a platform where users can visit and rent their next accommodation from the comfort of their own homes. Flatlooker offers a wide range of apartments for rent, which are inspected by experts to ensure they match the presented photos and videos. They have been in operation since 2016 and have already facilitated over 20,000 rentals. Their business model combines technology and real estate expertise to provide a fast and transparent service. For property owners, Flatlooker offers a team of experts and advanced technological approaches to accelerate the rental process. Users can easily find their dream accommodation by completing an online registration, conducting virtual tours, submitting applications, signing leases online, and having an expert from Flatlooker conduct the move-in inspection. Additionally, Flatlooker provides a dedicated manager to handle routine management requests through their application. The company has gained the trust of over 5,000 property owners and 20,000 tenants."
#   }
# }
# --------------------------------
# Enriching:  Nautal
# With URL:  https://www.nautal.com/
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  Smiler is a company that operates in the photography industry. They offer photoshoot experiences in various cities around the world, including popular destinations such as New York City, Paris, Rome, Barcelona, and Sydney. Customers can book personalized sessions with professional photographers to capture memorable moments during their city trips. Smiler provides a platform for photographers to showcase their work and connect with potential clients.
#
# Description of the company:  PerfectStay is a company that offers a wide selection of travel deals and packages at the best prices. They provide irresistible offers and flash sales with discounts of up to 70%. They guarantee the best price and will refund double the difference if customers find a cheaper option elsewhere. Payment can be made in installments, allowing customers to pay at their own pace. PerfectStay also offers a vacation guarantee, providing a replacement solution in case of unforeseen circumstances such as a health crisis or flight cancellation. Customers can easily and quickly book flights, hotels, activities, and transfers all in one place. The company provides 24/7 assistance to customers before, during, and after their trip. With over 700,000 satisfied travelers, PerfectStay aims to provide a unique and unforgettable travel experience.
#
# {
#   "index": 53,
#   "company_profile": {
#     "name": "Konfetti",
#     "website": "https://gokonfetti.com/de-de/",
#     "client_focus": "B2B/B2C",
#     "platform_tag": "Not Classified",
#     "description": "The company offers courses, gift ideas, and team events. They have a wide range of over 4,000 courses and experiences available. They provide various activities such as pottery classes, cocktail making courses, wine tastings, and art workshops. They also offer gift vouchers for these experiences. Additionally, they specialize in organizing team events and provide assistance in planning and offering customized options. The company operates in multiple cities and offers courses in categories such as cooking, crafts, art, and more."
#   }
# }
# --------------------------------
# Enriching:  Zizoo
# With URL:  https://www.zizoo.com/
#
# {
#   "index": 52,
#   "company_profile": {
#     "name": "Smiler",
#     "website": "https://smiler.co/en",
#     "client_focus": "B2C",
#     "platform_tag": "On-demand Platform",
#     "description": "Smiler is a company that operates in the photography industry. They offer photoshoot experiences in various cities around the world, including popular destinations such as New York City, Paris, Rome, Barcelona, and Sydney. Customers can book personalized sessions with professional photographers to capture memorable moments during their city trips. Smiler provides a platform for photographers to showcase their work and connect with potential clients."
#   }
# }
# --------------------------------
# Enriching:  Flatfair
# With URL:  https://flatfair.co.uk/
#
# {
#   "index": 51,
#   "company_profile": {
#     "name": "Perfectstay",
#     "website": "https://www.perfectstay.com/fr-FR",
#     "client_focus": "B2C",
#     "platform_tag": "Not Classified",
#     "description": "PerfectStay is a company that offers a wide selection of travel deals and packages at the best prices. They provide irresistible offers and flash sales with discounts of up to 70%. They guarantee the best price and will refund double the difference if customers find a cheaper option elsewhere. Payment can be made in installments, allowing customers to pay at their own pace. PerfectStay also offers a vacation guarantee, providing a replacement solution in case of unforeseen circumstances such as a health crisis or flight cancellation. Customers can easily and quickly book flights, hotels, activities, and transfers all in one place. The company provides 24/7 assistance to customers before, during, and after their trip. With over 700,000 satisfied travelers, PerfectStay aims to provide a unique and unforgettable travel experience."
#   }
# }
# --------------------------------
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The company, Appear Here, operates in the retail space industry. They provide a platform for individuals and businesses to rent retail spaces, venues, and pop-up shops in various cities around the world. They offer a wide range of locations, including Birmingham, Brighton, London, Manchester, New York, Paris, Miami, and Los Angeles. Their platform allows users to search for available spaces, view details and pricing, and make bookings securely online. Appear Here also ensures the quality and exclusivity of the spaces on their platform, with 90% of the spaces being unique and exclusive to them. They provide expert service throughout the booking process, with a concierge team available to assist users. Additionally, they offer a direct chat feature for users to communicate with landlords and coordinate the details of their tenancy.
#
# {
#   "index": 55,
#   "company_profile": {
#     "name": "appear here",
#     "website": "https://www.appearhere.co.uk/",
#     "client_focus": "B2B/B2C",
#     "platform_tag": "Product Marketplace",
#     "description": "The company, Appear Here, operates in the retail space industry. They provide a platform for individuals and businesses to rent retail spaces, venues, and pop-up shops in various cities around the world. They offer a wide range of locations, including Birmingham, Brighton, London, Manchester, New York, Paris, Miami, and Los Angeles. Their platform allows users to search for available spaces, view details and pricing, and make bookings securely online. Appear Here also ensures the quality and exclusivity of the spaces on their platform, with 90% of the spaces being unique and exclusive to them. They provide expert service throughout the booking process, with a concierge team available to assist users. Additionally, they offer a direct chat feature for users to communicate with landlords and coordinate the details of their tenancy."
#   }
# }
# --------------------------------
#
# Description of the company:  Zizoo is a yacht charter platform that offers boating holidays worldwide. They provide boat rentals and yacht charters in various popular destinations such as Croatia, Greece, Ibiza, Mallorca, Turkey, and more. With over 50,000 verified boats in their inventory, customers can choose their desired destination and find the perfect boat for their needs. Zizoo ensures a worry-free boating experience with 24/7 customer service and a best price guarantee. They also offer a personalized trip proposal through their Zizoo Quiz. Customers can book their boat rentals directly through the website and enjoy a seamless booking process with the assistance of Zizoo's professional and responsive team.
#
# {
#   "index": 57,
#   "company_profile": {
#     "name": "Zizoo",
#     "website": "https://www.zizoo.com/",
#     "client_focus": "B2C",
#     "platform_tag": "Product Marketplace",
#     "description": "Zizoo is a yacht charter platform that offers boating holidays worldwide. They provide boat rentals and yacht charters in various popular destinations such as Croatia, Greece, Ibiza, Mallorca, Turkey, and more. With over 50,000 verified boats in their inventory, customers can choose their desired destination and find the perfect boat for their needs. Zizoo ensures a worry-free boating experience with 24/7 customer service and a best price guarantee. They also offer a personalized trip proposal through their Zizoo Quiz. Customers can book their boat rentals directly through the website and enjoy a seamless booking process with the assistance of Zizoo's professional and responsive team."
#   }
# }
# --------------------------------
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# -> Retrieved text from website...
# -> Crafting company description...
#
# Description of the company:  The business, flatfair, provides rental solutions and protection for landlords and tenants. They offer a No Deposit solution, allowing tenants to rent a home without paying a deposit. Instead, tenants pay a small check-in fee and any damages are paid when they move out. This solution provides fast and easy renting for tenants, with lower upfront costs and quick move-ins. For landlords, flatfair offers market-leading protection, faster payouts, and up to double the protection compared to traditional deposits. Agents can also gain a competitive advantage by offering this innovative rental solution. flatfair aims to replace slow and outdated deposit schemes, unlocking cash deposits and streamlining the deposit process. They are already working with thousands of agents across the UK.
#
# Description of the company:  The business, Nautal, operates in the boat rental and boat charter industry. They provide a platform where customers can charter thousands of yachts worldwide, with or without a skipper. Customers can search for boats based on their place of departure, date of departure, date of return, and boat type (sailboat, motorboat, RIB, catamarans, gulets, jet skis, houseboats, boats without license, yachts). Nautal also showcases boats recommended by their clients and provides reviews from fellow sailors about their experiences.
#
# {
#   "index": 58,
#   "company_profile": {
#     "name": "Flatfair",
#     "website": "https://flatfair.co.uk/",
#     "client_focus": "B2B/B2C",
#     "platform_tag": "Financial Platforms",
#     "description": "The business, flatfair, provides rental solutions and protection for landlords and tenants. They offer a No Deposit solution, allowing tenants to rent a home without paying a deposit. Instead, tenants pay a small check-in fee and any damages are paid when they move out. This solution provides fast and easy renting for tenants, with lower upfront costs and quick move-ins. For landlords, flatfair offers market-leading protection, faster payouts, and up to double the protection compared to traditional deposits. Agents can also gain a competitive advantage by offering this innovative rental solution. flatfair aims to replace slow and outdated deposit schemes, unlocking cash deposits and streamlining the deposit process. They are already working with thousands of agents across the UK."
#   }
# }
# --------------------------------
#
# {
#   "index": 56,
#   "company_profile": {
#     "name": "Nautal",
#     "website": "https://www.nautal.com/",
#     "client_focus": "B2C",
#     "platform_tag": "Product Marketplace",
#     "description": "The business, Nautal, operates in the boat rental and boat charter industry. They provide a platform where customers can charter thousands of yachts worldwide, with or without a skipper. Customers can search for boats based on their place of departure, date of departure, date of return, and boat type (sailboat, motorboat, RIB, catamarans, gulets, jet skis, houseboats, boats without license, yachts). Nautal also showcases boats recommended by their clients and provides reviews from fellow sailors about their experiences."
#   }
# }
# --------------------------------

# %%
df.to_csv('MangoPay_Enriched.csv')
